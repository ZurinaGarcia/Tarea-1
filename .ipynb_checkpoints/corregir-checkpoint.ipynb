# %%
import os, pandas as pd
import numpy as np


# Leer los archivos de datos en dataframes

country_isos=pd.read_excel(os.path.join('country_isos.xlsx'))
poblacion=pd.read_csv(os.path.join("co2.csv"))
obesidad = pd.read_csv(os.path.join("obesidad.csv"))
gripe = pd.read_csv(os.path.join("annual-mortality-rate-from-seasonal-influenza-ages-65.csv"))

# %%
#LIMPIEZA DATA 1: Si mi variable seleccionada es la población por cada país en el año 2020

# Como mi fuente me brinda información de diversas fechas, porcedo a filtrar los datos de 2020 directamente en el DataFrame original
poblacion = poblacion[poblacion['year'] == 2020]

# Cambio en la selección de columnas específicas, por el nombre de columna "population"
poblacion = poblacion[['country', 'population']].rename(columns={'population': 'Population_in_2020'})
poblacion.reset_index(drop=True, inplace=True)

# Se hace cambio del nombre de la columna "country" a "Country" en el DataFrame original
poblacion.rename(columns={'country': 'Country'}, inplace=True)

# Se realiza el cambio del texto en la columna "Country" de minúsculas a mayúsculas en el DataFrame original
poblacion['Country'] = poblacion['Country'].str.upper()

# %%
#Revisando si la primera data está bien, obtenemos el siguiente resultado
poblacion
# Out:
#             Country  Population_in_2020
# 0       AFGHANISTAN        3.897224e+07
# 1            AFRICA        1.360677e+09
# 2      AFRICA (GCP)                 NaN
# 3     ALAND ISLANDS                 NaN
# 4           ALBANIA        2.866850e+06
# ..              ...                 ...
# 266  WESTERN SAHARA        5.560600e+05
# 267           WORLD        7.840953e+09
# 268           YEMEN        3.228404e+07
# 269          ZAMBIA        1.892772e+07
# 270        ZIMBABWE        1.566966e+07
#
# [271 rows x 2 columns]

# %%
#LIMPIAR DATA 2: índice de obesidad en adultos

# Reiniciar los índices después de ordenar, ya que vemos como estos mantienen las posiciones anteriores
obesidad.reset_index(drop=True, inplace=True)

# Se elimina la columna "Pos" y también es necesario cambiar el nombre de "Name" a "Country"
obesidad = obesidad.drop(columns=['Pos'])
obesidad = obesidad.rename(columns={'Name': 'Country'})

# Se cambia el nombre de la columna "Value" al nombre la variable para esta fuente "Obesity_adult_prevalence_rate"
obesidad = obesidad.rename(columns={'Value': 'Obesity_adult_prevalence_rate'})

# Se realiza el cambio del texto en la columna "Country", de minúsculas a mayúsculas
obesidad['Country'] = obesidad['Country'].str.upper()

#Finalmente se obtiene lo siguiente
obesidad
# Out:
#             Country  Obesity_adult_prevalence_rate
# 0    AMERICAN SAMOA                           74.6
# 1             NAURU                           71.1
# 2      COOK ISLANDS                           63.7
# 3           TOKELAU                           63.4
# 4             TONGA                           57.6
# ..              ...                            ...
# 186      MADAGASCAR                            1.6
# 187         ERITREA                            1.5
# 188           NEPAL                            1.4
# 189      BANGLADESH                            1.1
# 190        ETHIOPIA                            1.1
#
# [191 rows x 2 columns]

# %%
#LIMPIEZA DATA 3: El número anual de muertes por cada 100.000 personas en el grupo de edad de mayores de 65 años

# Cambiar el nombre de la columna "Entity" a "Country"
gripe = gripe.rename(columns={'Entity': 'Country'})

# Cambiar el texto en la columna "Country" de minúsculas a mayúsculas
gripe['Country'] = gripe['Country'].str.upper()


# Eliminar la columna "Year" y "Code"
gripe = gripe.drop(columns=['Year'])
gripe = gripe.drop(columns=['Code'])


# Cambiar el nombre de la columna "rate over 65" a "Country"
gripe = gripe.rename(columns={'rate over65': 'numero_anual_muertes'})

# %%
gripe
# Out:
#              Country  numero_anual_muertes
# 0        AFGHANISTAN                 62.57
# 1             AFRICA                 63.92
# 2            ALBANIA                 29.59
# 3            ALGERIA                 54.98
# 4           AMERICAS                 53.60
# ..               ...                   ...
# 195  WESTERN PACIFIC                 43.45
# 196            WORLD                 53.40
# 197            YEMEN                 58.73
# 198           ZAMBIA                 54.65
# 199         ZIMBABWE                 42.33
#
# [200 rows x 2 columns]

# %%
###########################################################################################################################

# %%
# Reviso los paises de cada una de mis datas, ver cuantos son distintos
OnlyPoblacion=set(poblacion.Country)-set(obesidad.Country)
OnlyObesidad=set(obesidad.Country)-set(poblacion.Country)

# %%
from thefuzz import process as fz
# Realizar los cambios
changeMerge1={f:fz.extractOne(f, OnlyPoblacion)[0] 
                 for f in sorted(OnlyPoblacion)
                 if fz.extractOne(f, OnlyPoblacion)[1] >=90}
changeMerge1
# Out:
# {'AFRICA': 'AFRICA',
#  'AFRICA (GCP)': 'AFRICA (GCP)',
#  'ALAND ISLANDS': 'ALAND ISLANDS',
#  'ANGUILLA': 'ANGUILLA',
#  'ANTARCTICA': 'ANTARCTICA',
#  'ARUBA': 'ARUBA',
#  'ASIA': 'ASIA',
#  'ASIA (EXCL. CHINA AND INDIA)': 'ASIA (EXCL. CHINA AND INDIA)',
#  'ASIA (GCP)': 'ASIA (GCP)',
#  'BAHAMAS': 'BAHAMAS',
#  'BERMUDA': 'BERMUDA',
#  'BONAIRE SINT EUSTATIUS AND SABA': 'BONAIRE SINT EUSTATIUS AND SABA',
#  'BRITISH VIRGIN ISLANDS': 'BRITISH VIRGIN ISLANDS',
#  'CAPE VERDE': 'CAPE VERDE',
#  'CENTRAL AMERICA (GCP)': 'CENTRAL AMERICA (GCP)',
#  'CHRISTMAS ISLAND': 'CHRISTMAS ISLAND',
#  'CONGO': 'CONGO',
#  'CURACAO': 'CURACAO',
#  'CZECHIA': 'CZECHIA',
#  'DEMOCRATIC REPUBLIC OF CONGO': 'DEMOCRATIC REPUBLIC OF CONGO',
#  'EAST TIMOR': 'EAST TIMOR',
#  'ESWATINI': 'ESWATINI',
#  'EUROPE': 'EUROPE',
#  'EUROPE (EXCL. EU-27)': 'EUROPE (EXCL. EU-27)',
#  'EUROPE (EXCL. EU-28)': 'EUROPE (EXCL. EU-28)',
#  'EUROPE (GCP)': 'EUROPE (GCP)',
#  'EUROPEAN UNION (27)': 'EUROPEAN UNION (27)',
#  'EUROPEAN UNION (27) (GCP)': 'EUROPEAN UNION (27) (GCP)',
#  'EUROPEAN UNION (28)': 'EUROPEAN UNION (28)',
#  'FALKLAND ISLANDS': 'FALKLAND ISLANDS',
#  'FAROE ISLANDS': 'FAROE ISLANDS',
#  'FRENCH EQUATORIAL AFRICA (JONES ET AL. 2023)': 'FRENCH EQUATORIAL AFRICA (JONES ET AL. 2023)',
#  'FRENCH GUIANA': 'FRENCH GUIANA',
#  'FRENCH POLYNESIA': 'FRENCH POLYNESIA',
#  'FRENCH WEST AFRICA (JONES ET AL. 2023)': 'FRENCH WEST AFRICA (JONES ET AL. 2023)',
#  'GAMBIA': 'GAMBIA',
#  'GREENLAND': 'GREENLAND',
#  'GUADELOUPE': 'GUADELOUPE',
#  'GUERNSEY': 'GUERNSEY',
#  'HIGH-INCOME COUNTRIES': 'HIGH-INCOME COUNTRIES',
#  'HONG KONG': 'HONG KONG',
#  'INTERNATIONAL TRANSPORT': 'INTERNATIONAL TRANSPORT',
#  'ISLE OF MAN': 'ISLE OF MAN',
#  'JERSEY': 'JERSEY',
#  'KOSOVO': 'KOSOVO',
#  'KUWAITI OIL FIRES (JONES ET AL. 2023)': 'KUWAITI OIL FIRES (JONES ET AL. 2023)',
#  'LEAST DEVELOPED COUNTRIES (JONES ET AL. 2023)': 'LEAST DEVELOPED COUNTRIES (JONES ET AL. 2023)',
#  'LEEWARD ISLANDS (JONES ET AL. 2023)': 'LEEWARD ISLANDS (JONES ET AL. 2023)',
#  'LIECHTENSTEIN': 'LIECHTENSTEIN',
#  'LOW-INCOME COUNTRIES': 'LOW-INCOME COUNTRIES',
#  'LOWER-MIDDLE-INCOME COUNTRIES': 'LOWER-MIDDLE-INCOME COUNTRIES',
#  'MACAO': 'MACAO',
#  'MARTINIQUE': 'MARTINIQUE',
#  'MAYOTTE': 'MAYOTTE',
#  'MICRONESIA (COUNTRY)': 'MICRONESIA (COUNTRY)',
#  'MIDDLE EAST (GCP)': 'MIDDLE EAST (GCP)',
#  'MONTSERRAT': 'MONTSERRAT',
#  'MYANMAR': 'MYANMAR',
#  'NETHERLANDS ANTILLES': 'NETHERLANDS ANTILLES',
#  'NEW CALEDONIA': 'NEW CALEDONIA',
#  'NIUE': 'NIUE',
#  'NON-OECD (GCP)': 'NON-OECD (GCP)',
#  'NORTH AMERICA': 'NORTH AMERICA',
#  'NORTH AMERICA (EXCL. USA)': 'NORTH AMERICA (EXCL. USA)',
#  'NORTH AMERICA (GCP)': 'NORTH AMERICA (GCP)',
#  'NORTH KOREA': 'NORTH KOREA',
#  'NORTH MACEDONIA': 'NORTH MACEDONIA',
#  'OCEANIA': 'OCEANIA',
#  'OCEANIA (GCP)': 'OCEANIA (GCP)',
#  'OECD (GCP)': 'OECD (GCP)',
#  'OECD (JONES ET AL. 2023)': 'OECD (JONES ET AL. 2023)',
#  'PALESTINE': 'PALESTINE',
#  'PANAMA CANAL ZONE (JONES ET AL. 2023)': 'PANAMA CANAL ZONE (JONES ET AL. 2023)',
#  'PUERTO RICO': 'PUERTO RICO',
#  'REUNION': 'REUNION',
#  'RYUKYU ISLANDS (JONES ET AL. 2023)': 'RYUKYU ISLANDS (JONES ET AL. 2023)',
#  'SAINT HELENA': 'SAINT HELENA',
#  'SAINT MARTIN (FRENCH PART)': 'SAINT MARTIN (FRENCH PART)',
#  'SAINT PIERRE AND MIQUELON': 'SAINT PIERRE AND MIQUELON',
#  'SINT MAARTEN (DUTCH PART)': 'SINT MAARTEN (DUTCH PART)',
#  'SOUTH AMERICA': 'SOUTH AMERICA',
#  'SOUTH AMERICA (GCP)': 'SOUTH AMERICA (GCP)',
#  'SOUTH KOREA': 'SOUTH KOREA',
#  'SOUTH SUDAN': 'SOUTH SUDAN',
#  'ST. KITTS-NEVIS-ANGUILLA (JONES ET AL. 2023)': 'ST. KITTS-NEVIS-ANGUILLA (JONES ET AL. 2023)',
#  'SVALBARD AND JAN MAYEN': 'SVALBARD AND JAN MAYEN',
#  'TAIWAN': 'TAIWAN',
#  'TURKS AND CAICOS ISLANDS': 'TURKS AND CAICOS ISLANDS',
#  'TUVALU': 'TUVALU',
#  'UNITED STATES VIRGIN ISLANDS': 'UNITED STATES VIRGIN ISLANDS',
#  'UPPER-MIDDLE-INCOME COUNTRIES': 'UPPER-MIDDLE-INCOME COUNTRIES',
#  'WALLIS AND FUTUNA': 'WALLIS AND FUTUNA',
#  'WESTERN SAHARA': 'WESTERN SAHARA',
#  'WORLD': 'WORLD'}

# %%
obesidad.Country.replace(to_replace=changeMerge1,inplace=True)

# %%
#segundo filtro
OnlyPoblacion=set(poblacion.Country)-set(obesidad.Country)
OnlyObesidad=set(obesidad.Country)-set(poblacion.Country)
[(f,fz.extractOne(f, OnlyPoblacion)) for f in sorted(OnlyObesidad)]
# Out:
# [('BAHAMAS, THE', ('BAHAMAS', 90)),
#  ('BURMA', ('BERMUDA', 67)),
#  ('CABO VERDE', ('CAPE VERDE', 80)),
#  ('CONGO, DEMOCRATIC REPUBLIC OF THE', ('DEMOCRATIC REPUBLIC OF CONGO', 95)),
#  ('CONGO, REPUBLIC OF THE', ('CONGO', 90)),
#  ('CZECH REPUBLIC', ('DEMOCRATIC REPUBLIC OF CONGO', 86)),
#  ('GAMBIA, THE', ('GAMBIA', 90)),
#  ('KOREA, NORTH', ('NORTH KOREA', 95)),
#  ('KOREA, SOUTH', ('SOUTH KOREA', 95)),
#  ('MACEDONIA', ('NORTH MACEDONIA', 90)),
#  ('MICRONESIA, FEDERATED STATES OF', ('ISLE OF MAN', 86)),
#  ('SWAZILAND', ('CHRISTMAS ISLAND', 60)),
#  ('TIMOR-LESTE', ('EAST TIMOR', 82)),
#  ('TOKELAU', ('EUROPEAN UNION (27)', 51))]

# %%
#Realizaré el primer merge entre mi dos de mis datas
merge_data1=poblacion.merge(obesidad,left_on='Country',right_on='Country')

# Revisando el resultado del primer merge
merge_data1
# Out:
#             Country  Population_in_2020  Obesity_adult_prevalence_rate
# 0       AFGHANISTAN          38972236.0                            2.2
# 1           ALBANIA           2866850.0                           21.3
# 2           ALGERIA          43451668.0                           16.0
# 3    AMERICAN SAMOA             46216.0                           74.6
# 4           ANDORRA             77723.0                           25.2
# ..              ...                 ...                            ...
# 172       VENEZUELA          28490458.0                           30.3
# 173         VIETNAM          96648680.0                            1.7
# 174           YEMEN          32284044.0                           14.5
# 175          ZAMBIA          18927716.0                            3.6
# 176        ZIMBABWE          15669663.0                            7.0
#
# [177 rows x 3 columns]

# %%
# Diferencia entre merge 1 y gripe
set(merge_data1.Country)-set(gripe.Country)
# Out:
# {'AMERICAN SAMOA',
#  'ANDORRA',
#  'COOK ISLANDS',
#  'DOMINICA',
#  'MARSHALL ISLANDS',
#  'NAURU',
#  'PALAU',
#  'SAINT KITTS AND NEVIS'}

# %%
# Como las datas que debo hacer son cuatro, debo realizar un nuevo merge, esta vez entre otra de mis datas
# y el realizado anteriormente
merge_data2=merge_data1.merge(gripe,left_on='Country',right_on='Country')

#revisando el resultado de este segundo merge
merge_data2
# Out:
#                  Country  Population_in_2020  Obesity_adult_prevalence_rate  \
# 0            AFGHANISTAN          38972236.0                            2.2
# 1                ALBANIA           2866850.0                           21.3
# 2                ALGERIA          43451668.0                           16.0
# 3                 ANGOLA          33428490.0                            6.4
# 4    ANTIGUA AND BARBUDA             92672.0                           25.6
# ..                   ...                 ...                            ...
# 164            VENEZUELA          28490458.0                           30.3
# 165              VIETNAM          96648680.0                            1.7
# 166                YEMEN          32284044.0                           14.5
# 167               ZAMBIA          18927716.0                            3.6
# 168             ZIMBABWE          15669663.0                            7.0
#
#      numero_anual_muertes
# 0                   62.57
# 1                   29.59
# 2                   54.98
# 3                   73.83
# 4                   42.39
# ..                    ...
# 164                 55.91
# 165                 37.39
# 166                 58.73
# 167                 54.65
# 168                 42.33
#
# [169 rows x 4 columns]

# %%
# Viendo las diferencias
set(country_isos.Country)-set(merge_data2.Country)
# Out:
# {'BAHAMAS (THE)',
#  'BOLIVIA (PLURINATIONAL STATE OF)',
#  'BRUNEI DARUSSALAM',
#  'CABO VERDE',
#  'CENTRAL AFRICAN REPUBLIC (THE)',
#  'COMOROS (THE)',
#  'CONGO (THE DEMOCRATIC REPUBLIC OF THE)',
#  'CONGO (THE)',
#  'CZECHIA',
#  "C√îTE D'IVOIRE",
#  'DOMINICAN REPUBLIC (THE)',
#  'ESWATINI',
#  'GAMBIA (THE)',
#  'IRAN (ISLAMIC REPUBLIC OF)',
#  'KOREA (THE REPUBLIC OF)',
#  "LAO PEOPLE'S DEMOCRATIC REPUBLIC (THE)",
#  'MICRONESIA (FEDERATED STATES OF)',
#  'MOLDOVA (THE REPUBLIC OF)',
#  'MYANMAR',
#  'NETHERLANDS (THE)',
#  'NIGER (THE)',
#  'NORTH MACEDONIA',
#  'PHILIPPINES (THE)',
#  'RUSSIAN FEDERATION (THE)',
#  'SOUTH SUDAN',
#  'SUDAN (THE)',
#  'TANZANIA, THE UNITED REPUBLIC OF',
#  'TIMOR-LESTE',
#  'UNITED ARAB EMIRATES (THE)',
#  'UNITED KINGDOM OF GREAT BRITAIN AND NORTHERN IRELAND (THE)',
#  'UNITED STATES MINOR OUTLYING ISLANDS (THE)',
#  'VIET NAM'}

# %%
# Finalmente, tenemos el merge del resultado de la unión de mis propias datas con las brindadas por el profesor 
merge_final=country_isos.merge(merge_data2,left_on='Country',right_on='Country')

# Revisando nuestro resultado, tenemos
merge_final
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The Oriental Republic of Uruguay
# 135           UZBEKISTAN                   The Republic of Uzbekistan
# 136                YEMEN                        The Republic of Yemen
# 137               ZAMBIA                       The Republic of Zambia
# 138             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3  Population_in_2020  \
# 0             .af   AF  AFG          38972236.0
# 1             .al   AL  ALB           2866850.0
# 2             .dz   DZ  DZA          43451668.0
# 3             .ao   AO  AGO          33428490.0
# 4             .ag   AG  ATG             92672.0
# ..            ...  ...  ...                 ...
# 134           .uy   UY  URY           3429087.0
# 135           .uz   UZ  UZB          33526662.0
# 136           .ye   YE  YEM          32284044.0
# 137           .zm   ZM  ZMB          18927716.0
# 138           .zw   ZW  ZWE          15669663.0
#
#      Obesity_adult_prevalence_rate  numero_anual_muertes
# 0                              2.2                 62.57
# 1                             21.3                 29.59
# 2                             16.0                 54.98
# 3                              6.4                 73.83
# 4                             25.6                 42.39
# ..                             ...                   ...
# 134                           24.8                 61.77
# 135                           15.1                 37.22
# 136                           14.5                 58.73
# 137                            3.6                 54.65
# 138                            7.0                 42.33
#
# [139 rows x 8 columns]

# %%
#creamos una copia para realizar una vista de lo que serían la data si eliminamos los países que contienen NaN en alguna
# de sus celdas
merge_final_copia = merge_final.copy()
filas_con_nan = merge_final_copia.isna().any(axis=1)
filas_con_nan = merge_final_copia[filas_con_nan]

filas_con_nan
merge_final_copia.dropna(axis=0, how='any', inplace=True)

# %%
# Ahora, con toda mi data, puedo realizar la limpieza final

# Quiero asegurarme que los datos en mi columnas sean de un tipo de valor coherente (Números)
# por lo que es necesario deshacerme de valores como NaN, que pueden ser un obstáculo en la aplicación de mi nueva data
merge_final.replace(np.nan,0,inplace=True) 

# Revisando el merge final
merge_final
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The Oriental Republic of Uruguay
# 135           UZBEKISTAN                   The Republic of Uzbekistan
# 136                YEMEN                        The Republic of Yemen
# 137               ZAMBIA                       The Republic of Zambia
# 138             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3  Population_in_2020  \
# 0             .af   AF  AFG          38972236.0
# 1             .al   AL  ALB           2866850.0
# 2             .dz   DZ  DZA          43451668.0
# 3             .ao   AO  AGO          33428490.0
# 4             .ag   AG  ATG             92672.0
# ..            ...  ...  ...                 ...
# 134           .uy   UY  URY           3429087.0
# 135           .uz   UZ  UZB          33526662.0
# 136           .ye   YE  YEM          32284044.0
# 137           .zm   ZM  ZMB          18927716.0
# 138           .zw   ZW  ZWE          15669663.0
#
#      Obesity_adult_prevalence_rate  numero_anual_muertes
# 0                              2.2                 62.57
# 1                             21.3                 29.59
# 2                             16.0                 54.98
# 3                              6.4                 73.83
# 4                             25.6                 42.39
# ..                             ...                   ...
# 134                           24.8                 61.77
# 135                           15.1                 37.22
# 136                           14.5                 58.73
# 137                            3.6                 54.65
# 138                            7.0                 42.33
#
# [139 rows x 8 columns]

# %%
# Cambiando el tipo de dato de las celdas de las columnas de mi data
merge_final['Obesity_adult_prevalence_rate'] = merge_final['Obesity_adult_prevalence_rate'].astype(str)
merge_final['Population_in_2020'] = merge_final['Population_in_2020'].astype(str)
merge_final['numero_anual_muertes'] = merge_final['numero_anual_muertes'].astype(str)

# Nos aseguramos de eliminar los espacios en blanco
merge_final.Obesity_adult_prevalence_rate.str.contains(pat=r'\d',regex=True)
merge_final.Population_in_2020.str.contains(pat=r'\d',regex=True)
merge_final.numero_anual_muertes.str.contains(pat=r'\d',regex=True)

# Verificamos la aplicación de los códigos
merge_final
# Out:
#                  Country                            Officialstatename  \
# 0            AFGHANISTAN          The Islamic Republic of Afghanistan
# 1                ALBANIA                      The Republic of Albania
# 2                ALGERIA  The People's Democratic Republic of Algeria
# 3                 ANGOLA                       The Republic of Angola
# 4    ANTIGUA AND BARBUDA                          Antigua and Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The Oriental Republic of Uruguay
# 135           UZBEKISTAN                   The Republic of Uzbekistan
# 136                YEMEN                        The Republic of Yemen
# 137               ZAMBIA                       The Republic of Zambia
# 138             ZIMBABWE                     The Republic of Zimbabwe
#
#     InternetccTLD iso2 iso3 Population_in_2020 Obesity_adult_prevalence_rate  \
# 0             .af   AF  AFG         38972236.0                           2.2
# 1             .al   AL  ALB          2866850.0                          21.3
# 2             .dz   DZ  DZA         43451668.0                          16.0
# 3             .ao   AO  AGO         33428490.0                           6.4
# 4             .ag   AG  ATG            92672.0                          25.6
# ..            ...  ...  ...                ...                           ...
# 134           .uy   UY  URY          3429087.0                          24.8
# 135           .uz   UZ  UZB         33526662.0                          15.1
# 136           .ye   YE  YEM         32284044.0                          14.5
# 137           .zm   ZM  ZMB         18927716.0                           3.6
# 138           .zw   ZW  ZWE         15669663.0                           7.0
#
#     numero_anual_muertes
# 0                  62.57
# 1                  29.59
# 2                  54.98
# 3                  73.83
# 4                  42.39
# ..                   ...
# 134                61.77
# 135                37.22
# 136                58.73
# 137                54.65
# 138                42.33
#
# [139 rows x 8 columns]

# %%
# Reemplazamos los valores en blanco, por guiones bajos
merge_final.rename(columns={'Officialstatename': 'Official_State_Name'}, inplace=True)
merge_final['Official_State_Name']=merge_final['Official_State_Name'].str.replace(' ','_',regex=True)
merge_final['Country']=merge_final['Country'].str.replace(' ','_',regex=True)

#Revisamos nuestra data
merge_final
# Out:
#                  Country                          Official_State_Name  \
# 0            AFGHANISTAN          The_Islamic_Republic_of_Afghanistan
# 1                ALBANIA                      The_Republic_of_Albania
# 2                ALGERIA  The_People's_Democratic_Republic_of_Algeria
# 3                 ANGOLA                       The_Republic_of_Angola
# 4    ANTIGUA_AND_BARBUDA                          Antigua_and_Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The_Oriental_Republic_of_Uruguay
# 135           UZBEKISTAN                   The_Republic_of_Uzbekistan
# 136                YEMEN                        The_Republic_of_Yemen
# 137               ZAMBIA                       The_Republic_of_Zambia
# 138             ZIMBABWE                     The_Republic_of_Zimbabwe
#
#     InternetccTLD iso2 iso3 Population_in_2020 Obesity_adult_prevalence_rate  \
# 0             .af   AF  AFG         38972236.0                           2.2
# 1             .al   AL  ALB          2866850.0                          21.3
# 2             .dz   DZ  DZA         43451668.0                          16.0
# 3             .ao   AO  AGO         33428490.0                           6.4
# 4             .ag   AG  ATG            92672.0                          25.6
# ..            ...  ...  ...                ...                           ...
# 134           .uy   UY  URY          3429087.0                          24.8
# 135           .uz   UZ  UZB         33526662.0                          15.1
# 136           .ye   YE  YEM         32284044.0                          14.5
# 137           .zm   ZM  ZMB         18927716.0                           3.6
# 138           .zw   ZW  ZWE         15669663.0                           7.0
#
#     numero_anual_muertes
# 0                  62.57
# 1                  29.59
# 2                  54.98
# 3                  73.83
# 4                  42.39
# ..                   ...
# 134                61.77
# 135                37.22
# 136                58.73
# 137                54.65
# 138                42.33
#
# [139 rows x 8 columns]

# %%
# Eliminar espacios en blanco
merge_final=merge_final.rename(columns=lambda x:x.strip())

# Finalmente, nuestro resultado final es el siguiente, considerando que los valores de NaN pasan a ser 0
merge_final
# Out:
#                  Country                          Official_State_Name  \
# 0            AFGHANISTAN          The_Islamic_Republic_of_Afghanistan
# 1                ALBANIA                      The_Republic_of_Albania
# 2                ALGERIA  The_People's_Democratic_Republic_of_Algeria
# 3                 ANGOLA                       The_Republic_of_Angola
# 4    ANTIGUA_AND_BARBUDA                          Antigua_and_Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The_Oriental_Republic_of_Uruguay
# 135           UZBEKISTAN                   The_Republic_of_Uzbekistan
# 136                YEMEN                        The_Republic_of_Yemen
# 137               ZAMBIA                       The_Republic_of_Zambia
# 138             ZIMBABWE                     The_Republic_of_Zimbabwe
#
#     InternetccTLD iso2 iso3 Population_in_2020 Obesity_adult_prevalence_rate  \
# 0             .af   AF  AFG         38972236.0                           2.2
# 1             .al   AL  ALB          2866850.0                          21.3
# 2             .dz   DZ  DZA         43451668.0                          16.0
# 3             .ao   AO  AGO         33428490.0                           6.4
# 4             .ag   AG  ATG            92672.0                          25.6
# ..            ...  ...  ...                ...                           ...
# 134           .uy   UY  URY          3429087.0                          24.8
# 135           .uz   UZ  UZB         33526662.0                          15.1
# 136           .ye   YE  YEM         32284044.0                          14.5
# 137           .zm   ZM  ZMB         18927716.0                           3.6
# 138           .zw   ZW  ZWE         15669663.0                           7.0
#
#     numero_anual_muertes
# 0                  62.57
# 1                  29.59
# 2                  54.98
# 3                  73.83
# 4                  42.39
# ..                   ...
# 134                61.77
# 135                37.22
# 136                58.73
# 137                54.65
# 138                42.33
#
# [139 rows x 8 columns]

# %%
merge_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        139 non-null    object
#  1   Official_State_Name            139 non-null    object
#  2   InternetccTLD                  139 non-null    object
#  3   iso2                           139 non-null    object
#  4   iso3                           139 non-null    object
#  5   Population_in_2020             139 non-null    object
#  6   Obesity_adult_prevalence_rate  139 non-null    object
#  7   numero_anual_muertes           139 non-null    object
# dtypes: object(8)
# memory usage: 8.8+ KB

# %%
# Arreglando el Dtype de algunas columnas
merge_final['Population_in_2020'] = merge_final['Population_in_2020'].astype('float64')
merge_final['Obesity_adult_prevalence_rate'] = merge_final['Obesity_adult_prevalence_rate'].astype('float64')
merge_final['numero_anual_muertes'] = merge_final['numero_anual_muertes'].astype('float64')

# %%
merge_final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 139 entries, 0 to 138
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        139 non-null    object
#  1   Official_State_Name            139 non-null    object
#  2   InternetccTLD                  139 non-null    object
#  3   iso2                           139 non-null    object
#  4   iso3                           139 non-null    object
#  5   Population_in_2020             139 non-null    float64
#  6   Obesity_adult_prevalence_rate  139 non-null    float64
#  7   numero_anual_muertes           139 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 8.8+ KB

# %%
merge_final_copia.rename(columns={'Officialstatename': 'Official_State_Name'}, inplace=True)
merge_final_copia['Official_State_Name']=merge_final_copia['Official_State_Name'].str.replace(' ','_',regex=True)
merge_final_copia['Country']=merge_final_copia['Country'].str.replace(' ','_',regex=True)
merge_final_copia['Population_in_2020'] = merge_final_copia['Population_in_2020'].astype('float64')
merge_final_copia['Obesity_adult_prevalence_rate'] = merge_final_copia['Obesity_adult_prevalence_rate'].astype('float64')
merge_final_copia['numero_anual_muertes'] = merge_final_copia['numero_anual_muertes'].astype('float64')
merge_final_copia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 138 entries, 0 to 138
# Data columns (total 8 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Country                        138 non-null    object
#  1   Official_State_Name            138 non-null    object
#  2   InternetccTLD                  138 non-null    object
#  3   iso2                           138 non-null    object
#  4   iso3                           138 non-null    object
#  5   Population_in_2020             138 non-null    float64
#  6   Obesity_adult_prevalence_rate  138 non-null    float64
#  7   numero_anual_muertes           138 non-null    float64
# dtypes: float64(3), object(5)
# memory usage: 9.7+ KB

# %%
merge_final_copia
# Out:
#                  Country                          Official_State_Name  \
# 0            AFGHANISTAN          The_Islamic_Republic_of_Afghanistan
# 1                ALBANIA                      The_Republic_of_Albania
# 2                ALGERIA  The_People's_Democratic_Republic_of_Algeria
# 3                 ANGOLA                       The_Republic_of_Angola
# 4    ANTIGUA_AND_BARBUDA                          Antigua_and_Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The_Oriental_Republic_of_Uruguay
# 135           UZBEKISTAN                   The_Republic_of_Uzbekistan
# 136                YEMEN                        The_Republic_of_Yemen
# 137               ZAMBIA                       The_Republic_of_Zambia
# 138             ZIMBABWE                     The_Republic_of_Zimbabwe
#
#     InternetccTLD iso2 iso3  Population_in_2020  \
# 0             .af   AF  AFG          38972236.0
# 1             .al   AL  ALB           2866850.0
# 2             .dz   DZ  DZA          43451668.0
# 3             .ao   AO  AGO          33428490.0
# 4             .ag   AG  ATG             92672.0
# ..            ...  ...  ...                 ...
# 134           .uy   UY  URY           3429087.0
# 135           .uz   UZ  UZB          33526662.0
# 136           .ye   YE  YEM          32284044.0
# 137           .zm   ZM  ZMB          18927716.0
# 138           .zw   ZW  ZWE          15669663.0
#
#      Obesity_adult_prevalence_rate  numero_anual_muertes
# 0                              2.2                 62.57
# 1                             21.3                 29.59
# 2                             16.0                 54.98
# 3                              6.4                 73.83
# 4                             25.6                 42.39
# ..                             ...                   ...
# 134                           24.8                 61.77
# 135                           15.1                 37.22
# 136                           14.5                 58.73
# 137                            3.6                 54.65
# 138                            7.0                 42.33
#
# [138 rows x 8 columns]

# %%
# Se tienen dos resultados merge_final_copia y merge_final:

# Considerando eliminar los países que contenían NaN
merge_final_copia
# Out:
#                  Country                          Official_State_Name  \
# 0            AFGHANISTAN          The_Islamic_Republic_of_Afghanistan
# 1                ALBANIA                      The_Republic_of_Albania
# 2                ALGERIA  The_People's_Democratic_Republic_of_Algeria
# 3                 ANGOLA                       The_Republic_of_Angola
# 4    ANTIGUA_AND_BARBUDA                          Antigua_and_Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The_Oriental_Republic_of_Uruguay
# 135           UZBEKISTAN                   The_Republic_of_Uzbekistan
# 136                YEMEN                        The_Republic_of_Yemen
# 137               ZAMBIA                       The_Republic_of_Zambia
# 138             ZIMBABWE                     The_Republic_of_Zimbabwe
#
#     InternetccTLD iso2 iso3  Population_in_2020  \
# 0             .af   AF  AFG          38972236.0
# 1             .al   AL  ALB           2866850.0
# 2             .dz   DZ  DZA          43451668.0
# 3             .ao   AO  AGO          33428490.0
# 4             .ag   AG  ATG             92672.0
# ..            ...  ...  ...                 ...
# 134           .uy   UY  URY           3429087.0
# 135           .uz   UZ  UZB          33526662.0
# 136           .ye   YE  YEM          32284044.0
# 137           .zm   ZM  ZMB          18927716.0
# 138           .zw   ZW  ZWE          15669663.0
#
#      Obesity_adult_prevalence_rate  numero_anual_muertes
# 0                              2.2                 62.57
# 1                             21.3                 29.59
# 2                             16.0                 54.98
# 3                              6.4                 73.83
# 4                             25.6                 42.39
# ..                             ...                   ...
# 134                           24.8                 61.77
# 135                           15.1                 37.22
# 136                           14.5                 58.73
# 137                            3.6                 54.65
# 138                            7.0                 42.33
#
# [138 rows x 8 columns]

# %%
# considerando el valor de NaN como 0
merge_final
# Out:
#                  Country                          Official_State_Name  \
# 0            AFGHANISTAN          The_Islamic_Republic_of_Afghanistan
# 1                ALBANIA                      The_Republic_of_Albania
# 2                ALGERIA  The_People's_Democratic_Republic_of_Algeria
# 3                 ANGOLA                       The_Republic_of_Angola
# 4    ANTIGUA_AND_BARBUDA                          Antigua_and_Barbuda
# ..                   ...                                          ...
# 134              URUGUAY             The_Oriental_Republic_of_Uruguay
# 135           UZBEKISTAN                   The_Republic_of_Uzbekistan
# 136                YEMEN                        The_Republic_of_Yemen
# 137               ZAMBIA                       The_Republic_of_Zambia
# 138             ZIMBABWE                     The_Republic_of_Zimbabwe
#
#     InternetccTLD iso2 iso3  Population_in_2020  \
# 0             .af   AF  AFG          38972236.0
# 1             .al   AL  ALB           2866850.0
# 2             .dz   DZ  DZA          43451668.0
# 3             .ao   AO  AGO          33428490.0
# 4             .ag   AG  ATG             92672.0
# ..            ...  ...  ...                 ...
# 134           .uy   UY  URY           3429087.0
# 135           .uz   UZ  UZB          33526662.0
# 136           .ye   YE  YEM          32284044.0
# 137           .zm   ZM  ZMB          18927716.0
# 138           .zw   ZW  ZWE          15669663.0
#
#      Obesity_adult_prevalence_rate  numero_anual_muertes
# 0                              2.2                 62.57
# 1                             21.3                 29.59
# 2                             16.0                 54.98
# 3                              6.4                 73.83
# 4                             25.6                 42.39
# ..                             ...                   ...
# 134                           24.8                 61.77
# 135                           15.1                 37.22
# 136                           14.5                 58.73
# 137                            3.6                 54.65
# 138                            7.0                 42.33
#
# [139 rows x 8 columns]

# %%
merge_final_copia.reset_index(drop=True, inplace=True)

# %%
merge_final_copia
# Out:
#                  Country                          Official_State_Name  \
# 0            AFGHANISTAN          The_Islamic_Republic_of_Afghanistan
# 1                ALBANIA                      The_Republic_of_Albania
# 2                ALGERIA  The_People's_Democratic_Republic_of_Algeria
# 3                 ANGOLA                       The_Republic_of_Angola
# 4    ANTIGUA_AND_BARBUDA                          Antigua_and_Barbuda
# ..                   ...                                          ...
# 133              URUGUAY             The_Oriental_Republic_of_Uruguay
# 134           UZBEKISTAN                   The_Republic_of_Uzbekistan
# 135                YEMEN                        The_Republic_of_Yemen
# 136               ZAMBIA                       The_Republic_of_Zambia
# 137             ZIMBABWE                     The_Republic_of_Zimbabwe
#
#     InternetccTLD iso2 iso3  Population_in_2020  \
# 0             .af   AF  AFG          38972236.0
# 1             .al   AL  ALB           2866850.0
# 2             .dz   DZ  DZA          43451668.0
# 3             .ao   AO  AGO          33428490.0
# 4             .ag   AG  ATG             92672.0
# ..            ...  ...  ...                 ...
# 133           .uy   UY  URY           3429087.0
# 134           .uz   UZ  UZB          33526662.0
# 135           .ye   YE  YEM          32284044.0
# 136           .zm   ZM  ZMB          18927716.0
# 137           .zw   ZW  ZWE          15669663.0
#
#      Obesity_adult_prevalence_rate  numero_anual_muertes
# 0                              2.2                 62.57
# 1                             21.3                 29.59
# 2                             16.0                 54.98
# 3                              6.4                 73.83
# 4                             25.6                 42.39
# ..                             ...                   ...
# 133                           24.8                 61.77
# 134                           15.1                 37.22
# 135                           14.5                 58.73
# 136                            3.6                 54.65
# 137                            7.0                 42.33
#
# [138 rows x 8 columns]
